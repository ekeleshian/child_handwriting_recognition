# %% [markdown]
# _Code to retrieve single words from text_

# %%
#Import external packages

import cv2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import sys, os

plt.rcParams['figure.figsize'] = (15.0, 9.0)

print("OpenCV: " + cv2.__version__)
print("Numpy: " + np.__version__)
print("Pandas: " + pd.__version__)
# Out:
# OpenCV: 3.1.0
# Numpy: 1.15.1
# Pandas: 0.23.4

# %%
# Import internal packages

#Hack to add parent directory to PYTHONPATH
sys.path.insert(0,os.path.abspath(".."))
from aux_functions.helpers import implt, resize
import words

# %%
IMG = "preprocessed_text"
image = cv2.imread(os.path.abspath("../..")+"/data/%s.jpeg" % IMG)
implt(image)

# %%
bBoxes = words.detection(image)
